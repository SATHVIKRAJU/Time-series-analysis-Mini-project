# %%
# %matplotlib inline 
import matplotlib.pylab
import numpy as np
import pandas as pd

# %%
# Window functions are like aggregation functions
# You can use them in conjunction with .resample() which will soon be a deferred operation

# %%
df = pd.DataFrame(np.random.randn(600, 3), index = pd.date_range('7/1/2016', freq = 'S', periods = 600), columns = ['A', 'B', 'C'])

# %%
#pd.rolling_mean(df, window = 2)[1:10] # in future versions you want to resample separately
r = df.rolling(window = 10)
#r.agg, r.apply, r.count, r.exclusions, r.max, r.median, r.name, r.quantile, r.kurt, r.cov, r.corr, r.aggregate, r.std, r.skew, r.sum, r.var
df.plot(style = 'k--')
r.mean().plot(style = 'k')

# %%
r.count()
# Out:
#                         A     B     C
# 2016-07-01 00:00:00   1.0   1.0   1.0
# 2016-07-01 00:00:01   2.0   2.0   2.0
# 2016-07-01 00:00:02   3.0   3.0   3.0
# 2016-07-01 00:00:03   4.0   4.0   4.0
# 2016-07-01 00:00:04   5.0   5.0   5.0
# 2016-07-01 00:00:05   6.0   6.0   6.0
# 2016-07-01 00:00:06   7.0   7.0   7.0
# 2016-07-01 00:00:07   8.0   8.0   8.0
# 2016-07-01 00:00:08   9.0   9.0   9.0
# 2016-07-01 00:00:09  10.0  10.0  10.0
# 2016-07-01 00:00:10  10.0  10.0  10.0
# 2016-07-01 00:00:11  10.0  10.0  10.0
# 2016-07-01 00:00:12  10.0  10.0  10.0
# 2016-07-01 00:00:13  10.0  10.0  10.0
# 2016-07-01 00:00:14  10.0  10.0  10.0
# 2016-07-01 00:00:15  10.0  10.0  10.0
# 2016-07-01 00:00:16  10.0  10.0  10.0
# 2016-07-01 00:00:17  10.0  10.0  10.0
# 2016-07-01 00:00:18  10.0  10.0  10.0
# 2016-07-01 00:00:19  10.0  10.0  10.0
# 2016-07-01 00:00:20  10.0  10.0  10.0
# 2016-07-01 00:00:21  10.0  10.0  10.0
# 2016-07-01 00:00:22  10.0  10.0  10.0
# 2016-07-01 00:00:23  10.0  10.0  10.0
# 2016-07-01 00:00:24  10.0  10.0  10.0
# 2016-07-01 00:00:25  10.0  10.0  10.0
# 2016-07-01 00:00:26  10.0  10.0  10.0
# 2016-07-01 00:00:27  10.0  10.0  10.0
# 2016-07-01 00:00:28  10.0  10.0  10.0
# 2016-07-01 00:00:29  10.0  10.0  10.0
# ...                   ...   ...   ...
# 2016-07-01 00:09:30  10.0  10.0  10.0
# 2016-07-01 00:09:31  10.0  10.0  10.0
# 2016-07-01 00:09:32  10.0  10.0  10.0
# 2016-07-01 00:09:33  10.0  10.0  10.0
# 2016-07-01 00:09:34  10.0  10.0  10.0
# 2016-07-01 00:09:35  10.0  10.0  10.0
# 2016-07-01 00:09:36  10.0  10.0  10.0
# 2016-07-01 00:09:37  10.0  10.0  10.0
# 2016-07-01 00:09:38  10.0  10.0  10.0
# 2016-07-01 00:09:39  10.0  10.0  10.0
# 2016-07-01 00:09:40  10.0  10.0  10.0
# 2016-07-01 00:09:41  10.0  10.0  10.0
# 2016-07-01 00:09:42  10.0  10.0  10.0
# 2016-07-01 00:09:43  10.0  10.0  10.0
# 2016-07-01 00:09:44  10.0  10.0  10.0
# 2016-07-01 00:09:45  10.0  10.0  10.0
# 2016-07-01 00:09:46  10.0  10.0  10.0
Anaconda3\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: pd.ewm_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(span=15,min_periods=2,adjust=True,ignore_na=False).mean()
#   from ipykernel import kernelapp as app
#                             A         B         C
# 2016-07-01 00:00:01 -1.453417  1.110489  0.035260
# 2016-07-01 00:00:02 -0.717147  0.840356  0.183330
# 2016-07-01 00:00:03 -0.536913  0.834722 -0.357889
# 2016-07-01 00:00:04 -0.560384  1.027373 -0.334191
# 2016-07-01 00:00:05 -0.650286  0.658107 -0.106284
# 2016-07-01 00:00:06 -0.445085  0.321662 -0.028786
# 2016-07-01 00:00:07 -0.628225  0.116060  0.097953
# 2016-07-01 00:00:08 -0.229987  0.329017 -0.097834
# 2016-07-01 00:00:09 -0.109940  0.230756 -0.338135

# %%
# can also easily plot a rolling average per column
df = pd.DataFrame(np.random.randn(1000, 4), index = pd.date_range('6/6/16', periods = 1000), columns = ['A', 'B', 'C', 'D'])

# %%
df.head()
# Out:
#                    A         B         C         D
# 2016-06-06 -0.292550 -2.250631  0.599076 -1.521643
# 2016-06-07 -0.674282  0.785309  0.094357  1.923626
# 2016-06-08  0.289722 -1.197631 -2.289196 -1.726133
# 2016-06-09  0.887039 -0.508429  1.100552 -1.244170
# 2016-06-10  0.903023 -0.412123  1.033900  0.146999

# %%
df = df.cumsum()
df.rolling(window = 50).sum().plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000018294CE58D0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000018294B9D080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000018293B00780>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000182939812E8>], dtype=object)

# %%
# What about a custom function?
df.rolling(window = 10).apply(lambda x: np.fabs(x - x.mean()).mean())
# Out:
#                    A         B         C         D
# 2016-06-06       NaN       NaN       NaN       NaN
# 2016-06-07       NaN       NaN       NaN       NaN
# 2016-06-08       NaN       NaN       NaN       NaN
# 2016-06-09       NaN       NaN       NaN       NaN
# 2016-06-10       NaN       NaN       NaN       NaN
# 2016-06-11       NaN       NaN       NaN       NaN
# 2016-06-12       NaN       NaN       NaN       NaN
# 2016-06-13       NaN       NaN       NaN       NaN
# 2016-06-14       NaN       NaN       NaN       NaN
# 2016-06-15  1.710392  1.020678  0.900737  0.711317
# 2016-06-16  1.534222  1.097115  1.135874  0.654461
# 2016-06-17  1.388957  0.896042  1.265881  0.375723
# 2016-06-18  1.202385  0.883164  1.167709  0.472579
# 2016-06-19  1.143478  0.927253  1.062855  0.454310
# 2016-06-20  1.273700  1.129370  0.892731  0.469764
# 2016-06-21  1.353165  1.417466  0.865443  0.551696
# 2016-06-22  1.227350  1.801674  0.771565  0.594545
# 2016-06-23  0.902703  1.965228  0.624409  0.607291
# 2016-06-24  0.665204  2.090189  0.580453  0.737249
# 2016-06-25  0.585543  2.096863  0.635372  0.966691
# 2016-06-26  0.436166  1.817491  0.702865  1.185625
# 2016-06-27  0.522141  1.703867  0.672060  1.330470
# 2016-06-28  0.595581  1.625681  0.772694  1.217583
# 2016-06-29  0.676152  1.357781  0.667836  1.232595
# 2016-06-30  0.708060  1.124631  0.544437  1.250775
# 2016-07-01  0.692468  1.104835  0.445124  1.341738
# 2016-07-02  0.687254  0.957505  0.541244  1.598040
# 2016-07-03  0.655014  0.932064  0.445161  1.843845
# 2016-07-04  0.567320  0.788891  0.509243  1.897293
# 2016-07-05  0.375865  0.826201  0.592905  1.896472
# ...              ...       ...       ...       ...
# 2019-02-01  0.755323  0.824695  0.330309  1.127612
# 2019-02-02  0.937361  0.739018  0.360315  0.971218
# 2019-02-03  0.982678  0.676245  0.333788  0.700586
# 2019-02-04  0.893889  0.672973  0.342448  0.686245
# 2019-02-05  0.759717  0.703683  0.328910  0.689164
# 2019-02-06  0.781529  0.812720  0.497611  0.696204
# 2019-02-07  0.749847  0.819756  0.484391  0.761180
# 2019-02-08  0.758316  0.942302  0.483308  0.928391
# 2019-02-09  0.907150  0.942902  0.575192  0.938610
# 2019-02-10  1.032310  1.001037  0.542815  0.868614
# 2019-02-11  1.068008  1.073165  0.500723  0.894226
# 2019-02-12  0.970115  0.984557  0.501330  0.963730
# 2019-02-13  1.108975  0.757771  0.538394  1.113963
# 2019-02-14  1.084002  0.886361  0.587714  1.202289
# 2019-02-15  1.020988  0.748955  0.724229  1.227785
# 2019-02-16  0.892050  0.861123  0.953247  1.284482
# 2019-02-17  1.124654  1.017328  1.224075  1.163525
# 2019-02-18  1.315788  1.042070  1.365623  0.989402
# 2019-02-19  1.170374  0.950647  1.602841  0.906724
# 2019-02-20  1.189873  0.914045  1.731258  0.894878
# 2019-02-21  1.146082  0.910722  1.579876  0.971755
# 2019-02-22  1.148713  0.922898  1.267527  1.100892
# 2019-02-23  0.988625  1.088419  0.801126  1.157645
# 2019-02-24  0.869130  1.113151  0.591944  1.203845
# 2019-02-25  0.827207  1.310811  0.443115  1.212510
# 2019-02-26  0.738196  1.307505  0.414374  1.162591
# 2019-02-27  0.681857  1.048411  0.431430  1.326602
# 2019-02-28  0.529313  1.126985  0.514960  1.439913
# 2019-03-01  0.619384  1.192319  0.770350  1.504440
# 2019-03-02  0.553129  1.268610  0.947845  1.450611
#
# [1000 rows x 4 columns]

# %%
# Expanding windows
# Yields the value of the statistic with all the data available up to that point in time
df.expanding(min_periods = 1).mean()[1:5]
# Out:
#                    A         B         C         D
# 2016-06-07 -0.629691 -1.857977  0.646255 -0.559830
# 2016-06-08 -0.645497 -2.126302 -0.101084 -0.814603
# 2016-06-09 -0.431641 -2.387572 -0.199615 -1.253033
# 2016-06-10 -0.122722 -2.626759 -0.051954 -1.486690

# %%
# Will an expanding window provide a more or less stable statistic than a rolling statistic? 
# When might one vs. the other be appropriate?

If you are adding more users you would need to include the older data as well as the new data that is kicking in and hence the need for a expanding window as opposed to  rolling window.

# %%
# EWMA
# Why use EWMA?
#EWMA  ensures a variance that is weighted or biased toward more recent data

# %%
# Go do it!
# pandas.pydata.org/pandas-docs/stable/computation.html#stats-aggregate

# %%
# Come up with a series that shows how EWMA and Rolling can importantly differ even with the same window setting

# %%
dfa = pd.Series(np.random.randn(1000),index=pd.date_range('1/1/2000', periods=1000))

# %%
dfa.head()
# Out:
# 2000-01-01    0.228689
# 2000-01-02   -1.031679
# 2000-01-03    1.500494
# 2000-01-04    1.558875
# 2000-01-05    1.340491
# Freq: D, dtype: float64

# %%
dfa.ewma(span=60,freq='D',min_periods=0,adjust=True).mean().plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-75e047cfa6ce> in <module>()
# ----> 1 dfa.ewma(span=60,freq='D',min_periods=0,adjust=True).mean().plot()
#
# C:\Users\Sathvik\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'ewma'
